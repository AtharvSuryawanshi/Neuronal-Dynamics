# %% [markdown]
# # Just tutorials
# Here we find out what the fuck is going on with the code!

# %%
import numpy as np # type: ignore
import matplotlib.pyplot as plt # type: ignore
from scipy.integrate import odeint # type: ignore
import matplotlib.animation as animation 
from neuron_model import NeuronModel

# %%
model = NeuronModel('saddle-node') # ['saddle-node', 'SNIC', 'subcritical_Hopf', 'supercritical_Hopf']
t = np.linspace(0, 10, 100)  # Time points
step_time = 2  # Step starts at t=2
step_duration = 3  # Lasts for 3 time units
baseline = 0  # Baseline current
amplitude = 1  # Amplitude of the step

dt = 0.01
t = 100
I_ext = 0.1*np.arange(0, t, dt)
a = model.simulate(t, dt, [-70, 0.3], I_ext)
# model.find_equlibrium_points(I_ext, [-70, 30], len(I_ext))

# %%
fig, axs = plt.subplots(2, 1, gridspec_kw={'height_ratios': [3, 1]})
fig.suptitle("Hodgkin-Huxley model")
axs[0].plot(a[0], a[1][:, 0])
axs[0].set_xticks([])
axs[0].set_ylabel("Membrane potential (mV)")
axs[1].plot(a[0], I_ext)
axs[1].set_xlabel("Time (ms)")
axs[1].set_ylabel("I_ext ($uA/cm^2$)")
plt.tight_layout()
plt.show()

plt.figure()
plt.plot(a[1][:, 0], a[1][:, 1])
plt.title("Phase plot") 
plt.xlabel("Membrane potential (mV)")   
plt.ylabel("n") 
plt.show()

# %%
t = np.arange(0, 100, 0.01)
step_current = model.create_step_current(t,5, 10, 0.1, 1)
plt.plot(t, step_current)
plt.show()

# %%
t = np.arange(0, 100, 0.01)
ramp_current = model.create_ramp_current(t, 5, 90, 0.1, 1)
plt.plot(t, ramp_current)           
plt.show()

# %%
I_ext = 0.1*np.arange(0, 5000, 0.1)
model.find_equlibrium_points(I_ext, [-60, 10], 50000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 I_ext = 0.1*np.arange(0, 5000, 0.1)
# ----> 2 model.find_equlibrium_points(I_ext, [-60, 10], 50000)
#
# File c:\Users\Dell\Documents\GitHub\Neuronal-Dynamics\neuron_model.py:200, in NeuronModel.find_equlibrium_points(self, I_ext, x_range, num_points)
#     197 dV3, dn3 = self.dALLdt([V, n+eps], 0, lambda t: I_ext)
#     198 dV4, dn4 = self.dALLdt([V, n-eps], 0, lambda t: I_ext)
# --> 200 J = np.array([
#     201     [(dV1 - dV2)/(2*eps), (dV3 - dV4)/(2*eps)],
#     202     [(dn1 - dn2)/(2*eps), (dn3 - dn4)/(2*eps)]
#     203 ])
#     205 # Get eigenvalues
#     206 eigenvals = np.linalg.eigvals(J)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (2, 2) + inhomogeneous part.
